# %%
import pandas as pd
df = pd.read_csv("jaipur-modified-year.csv")
df
# Out:
#       year  month  day  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     2019      1    1        24        12           0.0      8.7        5
# 1     2019      1    1        24        12           0.0      8.7        5
# 2     2019      1    1        24        12           0.0      8.7        5
# 3     2019      1    1        24        12           0.0      8.7        5
# 4     2019      1    1        24        12           0.0      8.7        5
# ...    ...    ...  ...       ...       ...           ...      ...      ...
# 8777  2020      1    1        19         8           0.0      8.7        4
# 8778  2020      1    1        19         8           0.0      8.7        4
# 8779  2020      1    1        19         8           0.0      8.7        4
# 8780  2020      1    1        19         8           0.0      8.7        4
# 8781  2020      1    1        19         8           0.0      8.7        4
#
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df["month"],df["windspeedKmph"])

# %%
# df['month-2'] = df['month']
df.insert(4,"month-2","Any")
df['month-2'] = df['month']**2
plt.scatter(df["month"],df["maxtempC"])

# %%
import pandas as pd
data = ["pune","delhi","bombay","hyderabad","jaipur","nagpur","bengaluru","kanpur"]
for i in data:
    df = pd.read_csv(i+"-modified-year.csv")
    req = [ "mintempC", "maxtempC", "windspeedKmph","humidity","day","month"]
    for j in df.columns.values:
        if j in req:
            pass
        else :
            df.drop(j,axis =1,inplace=True)
    df.to_csv(i+"-modified-year.csv")
